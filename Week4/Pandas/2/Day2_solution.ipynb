# %% [markdown]
# # Instructor Turn Activity 1: Loc and iLoc
#
# ## Explanation:
# ## DataFrame.iloc
# #### Purely integer-location based indexing for selection by position.
# #### .iloc[ ] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# ## DataFrame.loc
# #### Purely label-location based indexer for selection by label.
#
# #### .loc[ ] is primarily label based, but may also be used with a boolean array.

# %%
import pandas as pd

# %%
file = "Resources/sampleData.csv"

# %%
df_original = pd.read_csv(file)
df_original.head()
# Out:
#    id first_name   last_name       Phone Number      Time zone
# 0   1      Peter  Richardson    7-(789)867-9023  Europe/Moscow
# 1   2     Janice       Berry   86-(614)973-1727    Asia/Harbin
# 2   3     Andrea      Hudson   86-(918)527-6371  Asia/Shanghai
# 3   4     Arthur    Mcdonald  420-(553)779-7783  Europe/Prague
# 4   5      Kathy     Morales  351-(720)541-2124  Europe/Lisbon

# %%
# Set new index to last_name
df = df_original.set_index("last_name")
df.head()
# Out:
#             id first_name       Phone Number      Time zone
# last_name
# Richardson   1      Peter    7-(789)867-9023  Europe/Moscow
# Berry        2     Janice   86-(614)973-1727    Asia/Harbin
# Hudson       3     Andrea   86-(918)527-6371  Asia/Shanghai
# Mcdonald     4     Arthur  420-(553)779-7783  Europe/Prague
# Morales      5      Kathy  351-(720)541-2124  Europe/Lisbon

# %%
# Grab the data contained within the "Berry" row and the "Phone Number" column
berry_phone = df.loc["Berry", "Phone Number"]
print("Using Loc: " + berry_phone)

also_berry_phone = df.iloc[1, 2]
print("Using Iloc: " + also_berry_phone)
# Out:
# Using Loc: 86-(614)973-1727
# Using Iloc: 86-(614)973-1727

# %%
# Grab the first five rows of data and the columns from "id" to "Phone Number"
# The problem with using "last_name" as the index is that the values are not unique so duplicates are returned
# If there are duplicates and loc[] is being used, Pandas will return an error
richardson_to_morales = df.loc[["Richardson", "Berry", "Hudson",
                                "Mcdonald", "Morales"], ["id", "first_name", "Phone Number"]]
print(richardson_to_morales)

print()

# Using iloc[] will not find duplicates since a numeric index is always unique
also_richardson_to_morales = df.iloc[0:4, 0:3]
print(also_richardson_to_morales)
# Out:
#             id first_name       Phone Number
# last_name
# Richardson   1      Peter    7-(789)867-9023
# Richardson  25     Donald   62-(259)282-5871
# Berry        2     Janice   86-(614)973-1727
# Hudson       3     Andrea   86-(918)527-6371
# Hudson       8    Frances   57-(752)864-4744
# Hudson      90      Norma  351-(551)598-1822
# Mcdonald     4     Arthur  420-(553)779-7783
# Morales      5      Kathy  351-(720)541-2124
#
#             id first_name       Phone Number
# last_name
# Richardson   1      Peter    7-(789)867-9023
# Berry        2     Janice   86-(614)973-1727
# Hudson       3     Andrea   86-(918)527-6371
# Mcdonald     4     Arthur  420-(553)779-7783

# %%
# The following will select all rows for columns `first_name` and `Phone Number`
df.loc[:, ["first_name", "Phone Number"]].head()
# Out:
#            first_name       Phone Number
# last_name
# Richardson      Peter    7-(789)867-9023
# Berry          Janice   86-(614)973-1727
# Hudson         Andrea   86-(918)527-6371
# Mcdonald       Arthur  420-(553)779-7783
# Morales         Kathy  351-(720)541-2124

# %%
# the following logic test/conditional statement returns a series of boolean values
named_billy = df["first_name"] == "Billy"
named_billy.head()
# Out:
# last_name
# Richardson    False
# Berry         False
# Hudson        False
# Mcdonald      False
# Morales       False
# Name: first_name, dtype: bool

# %%
# Loc and Iloc also allow for conditional statments to filter rows of data
# using Loc on the logic test above only returns rows where the result is True
only_billys = df.loc[df["first_name"] == "Billy", :]
print(only_billys)

print()

# Multiple conditions can be set to narrow down or widen the filter
only_billy_and_peter = df.loc[(df["first_name"] == "Billy") | (df["first_name"] == "Peter"), :]
print(only_billy_and_peter)
# Out:
#            id first_name      Phone Number       Time zone
# last_name
# Clark      20      Billy  62-(213)345-2549   Asia/Makassar
# Andrews    23      Billy  86-(859)746-5367  Asia/Chongqing
# Price      59      Billy  86-(878)547-7739   Asia/Shanghai
#
#             id first_name      Phone Number       Time zone
# last_name
# Richardson   1      Peter   7-(789)867-9023   Europe/Moscow
# Clark       20      Billy  62-(213)345-2549   Asia/Makassar
# Andrews     23      Billy  86-(859)746-5367  Asia/Chongqing
# Price       59      Billy  86-(878)547-7739   Asia/Shanghai

# %% [markdown]
# ## Students Turn Activity 2: Good Movies
#
# ### Instructions
#
#   * Use Pandas to load and display the CSV provided in `Resources`.
#
#   * List all the columns in the data set.
#
#   * We're only interested in IMDb data, so create a new table that takes the Film and all the columns relating to IMDB.
#
#   * Filter out only the good movies—i.e., any film with an IMDb score greater than or equal to 7 and remove the norm ratings.
#
#   * Find less popular movies that you may not have heard about - i.e., anything with under 20K votes
#
#   * Finally, export this file to a spreadsheet, excluding the index, so we can keep track of our future watchlist.

# %%
# Dependencies
import pandas as pd

# %%
# Load in File
movie_file = "Resources/movie_scores.csv"

# %%
# Read and display with pandas
movie_file_pd = pd.read_csv(movie_file)
movie_file_pd.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0     3.70           4.3         ...                3.90            3.5
# 1     4.25           4.0         ...                3.55            4.5
# 2     4.00           4.5         ...                3.90            4.0
# 3     0.90           4.2         ...                2.70            1.0
# 4     0.70           1.4         ...                2.55            0.5
#
#    RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                 4.5                    3.5                         3.5
# 1                 4.0                    3.5                         4.0
# 2                 4.5                    3.0                         4.0
# 3                 4.0                    1.0                         2.5
# 4                 1.5                    1.5                         1.5
#
#    IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# 0              4.0                        1330                271107
# 1              3.5                         249                 65709
# 2              4.0                         627                103660
# 3              2.5                          31                  3136
# 4              2.5                          88                 19560
#
#    Fandango_votes  Fandango_Difference
# 0           14846                  0.5
# 1           12640                  0.5
# 2           12055                  0.5
# 3            1793                  0.5
# 4            1021                  0.5
#
# [5 rows x 22 columns]

# %%
# List all the columns the table provides
movie_file_pd.columns
# Out:
# Index(['FILM', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Metacritic_user_vote_count', 'IMDB_user_vote_count',
#        'Fandango_votes', 'Fandango_Difference'],
#       dtype='object')

# %%
# only care about Imdb, so create a new table that takes the Film and all the columns relating to IMDB
imdb_table = movie_file_pd[["FILM", "IMDB", "IMDB_norm", "IMDB_norm_round", "IMDB_user_vote_count"]]
imdb_table.head()
# Out:
#                              FILM  IMDB  IMDB_norm  IMDB_norm_round  \
# 0  Avengers: Age of Ultron (2015)   7.8       3.90              4.0
# 1               Cinderella (2015)   7.1       3.55              3.5
# 2                  Ant-Man (2015)   7.8       3.90              4.0
# 3          Do You Believe? (2015)   5.4       2.70              2.5
# 4   Hot Tub Time Machine 2 (2015)   5.1       2.55              2.5
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
# List only movies whose ratings are over 7 (out of 10) in IMDB
good_movies = movie_file_pd.loc[movie_file_pd["IMDB"] > 7, ["FILM", "IMDB", "IMDB_user_vote_count"]]
good_movies.head()
# Out:
#                              FILM  IMDB  IMDB_user_vote_count
# 0  Avengers: Age of Ultron (2015)   7.8                271107
# 1               Cinderella (2015)   7.1                 65709
# 2                  Ant-Man (2015)   7.8                103660
# 5        The Water Diviner (2015)   7.2                 39373
# 8    Shaun the Sheep Movie (2015)   7.4                 12227

# %%
# Find lesser-known movies to watch, with fewer than 20K votes
unknown_movies = good_movies.loc[good_movies["IMDB_user_vote_count"] < 20000, ["FILM", "IMDB", "IMDB_user_vote_count"]]
unknown_movies.head()
# Out:
#                                  FILM  IMDB  IMDB_user_vote_count
# 8        Shaun the Sheep Movie (2015)   7.4                 12227
# 9                 Love & Mercy (2015)   7.8                  5367
# 10  Far From The Madding Crowd (2015)   7.2                 12129
# 20              McFarland, USA (2015)   7.5                 13769
# 29         The End of the Tour (2015)   7.9                  1320

# %%
# Finally, export this file to an Excel spreadsheet -- without the DataFrame index.
unknown_movies.to_excel("output/movieWatchlist.xlsx", index=False)

# %% [markdown]
# # Instructor Turn Activity 3: Cleaning Data

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = 'Resources/donors2008_unclean.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
# Out:
#   LastName FirstName          Employer      City State    Zip  Amount  FIELD8
# 0    Aaron    Eugene  State Department    Dulles    VA  20189   500.0     NaN
# 1    Abadi   Barbara       Abadi & Co.  New York    NY  10021   200.0     NaN
# 2  Adamany   Anthony           Retired  Rockford    IL  61103   500.0     NaN
# 3    Adams  Lorraine              Self  New York    NY  10026   200.0     NaN
# 4    Adams    Marion              None    Exeter    NH  03833   100.0     NaN

# %%
# Delete extraneous column
del df['FIELD8']
df.head()
# Out:
#   LastName FirstName          Employer      City State    Zip  Amount
# 0    Aaron    Eugene  State Department    Dulles    VA  20189   500.0
# 1    Abadi   Barbara       Abadi & Co.  New York    NY  10021   200.0
# 2  Adamany   Anthony           Retired  Rockford    IL  61103   500.0
# 3    Adams  Lorraine              Self  New York    NY  10026   200.0
# 4    Adams    Marion              None    Exeter    NH  03833   100.0

# %%
# Identify incomplete rows
df.count()
# Out:
# LastName     1776
# FirstName    1776
# Employer     1743
# City         1776
# State        1776
# Zip          1776
# Amount       1776
# dtype: int64

# %%
# Drop all rows with missing information
# Return object with labels on given axis omitted where alternately any or all of the data are missing
# any if any NA values are present drop that label
# all if all values are NA drop that label
df = df.dropna(how='any')
df.head()
# Out:
#   LastName FirstName          Employer      City State    Zip  Amount
# 0    Aaron    Eugene  State Department    Dulles    VA  20189   500.0
# 1    Abadi   Barbara       Abadi & Co.  New York    NY  10021   200.0
# 2  Adamany   Anthony           Retired  Rockford    IL  61103   500.0
# 3    Adams  Lorraine              Self  New York    NY  10026   200.0
# 4    Adams    Marion              None    Exeter    NH  03833   100.0

# %%
# Verify dropped rows# Verif 
df.count()
# Out:
# LastName     1743
# FirstName    1743
# Employer     1743
# City         1743
# State        1743
# Zip          1743
# Amount       1743
# dtype: int64

# %%
# The Amount column is the wrong data type. It should be numeric.
df.dtypes
# Out:
# LastName      object
# FirstName     object
# Employer      object
# City          object
# State         object
# Zip           object
# Amount       float64
# dtype: object

# %%
# Use pd.to_numeric() method to convert the datatype of the Amount column
df['Amount'] = pd.to_numeric(df['Amount'])

# %%
# Verify that the Amount column datatype has been made numeric
df['Amount'].dtype
# Out:
# dtype('float64')

# %%
# Display an overview of the Employers column
df['Employer'].value_counts()
# Out:
# None                                                   249
# Self                                                   241
# Retired                                                126
# Self Employed                                           39
# Self-Employed                                           34
# Google                                                   6
# Not Employed                                             4
# Unemployed                                               4
# Social Security Administration                           3
# University of California                                 3
# Bank Of America                                          3
# CSC                                                      2
# Skadden, Arps                                            2
# Quadrangle Group                                         2
# University Of Michigan                                   2
# Sidley Austin LLP                                        2
# Kaiser Permanente                                        2
# Mayer Brown                                              2
# Newton Public Schools                                    2
# Davis Polk & Wardwell                                    2
# Ariel Investments                                        2
# Berger & Montague                                        2
# Hugo Neu Corporation                                     2
# University Hospital                                      2
# Mayer Brown LLP                                          2
# United Health Group                                      2
# Covington & Burling                                      2
# University of Washington                                 2
# Google, Inc.                                             2
# LMI                                                      2
#                                                       ...
# Self  Employed                                           1
# Oswego Boces                                             1
# Geary Porter And Donovan                                 1
# Baker Hostetler                                          1
# Inland Valley Infectious Disease Med Grp                 1
# EAG LLC                                                  1
# Navy (Retired)                                           1
# Seneca Strategy Partners, Inc.                           1
# Fox                                                      1
# World Bank Group: International Finance Corporation      1
# The Torrey Funds                                         1
# Presidio Pharmaceuticals                                 1
# Westec Corporation                                       1
# USIP                                                     1
# State Of Arizona                                         1
# Natural Health Technologies, Inc                         1
# Michael H. Berman, P.C.                                  1
# Frank's Fabrics, Inc.                                    1
# Virginia Commonwealth University Health System           1
# NOOR GROUP                                               1
# Florida A&M Univ. College of Law                         1
# KLA-Tencor Corp                                          1
# Brown University                                         1
# Better Life Communications                               1
# Dupage Medical Group                                     1
# Larry Bell Inc                                           1
# Murray Pacific                                           1
# AUD                                                      1
# Hirson,Inc                                               1
# Foley And Lardner                                        1
# Name: Employer, Length: 1011, dtype: int64

# %%
# Clean up Employer category. Replace 'Self Employed' and 'Self' with 'Self-Employed'
df['Employer'] = df['Employer'].replace(
    {'Self Employed': 'Self-Employed', 'Self': 'Self-Employed'})

# %%
# Verify clean-up.
df['Employer'].value_counts()
# Out:
# Self-Employed                                          314
# None                                                   249
# Retired                                                126
# Google                                                   6
# Unemployed                                               4
# Not Employed                                             4
# Social Security Administration                           3
# University of California                                 3
# Bank Of America                                          3
# University Hospital                                      2
# Newton Public Schools                                    2
# Skadden, Arps                                            2
# Quadrangle Group                                         2
# University Of Michigan                                   2
# LMI                                                      2
# Mayer Brown                                              2
# CSC                                                      2
# Kaiser Permanente                                        2
# Davis Polk & Wardwell                                    2
# Ariel Investments                                        2
# Berger & Montague                                        2
# Hugo Neu Corporation                                     2
# Mayer Brown LLP                                          2
# United Health Group                                      2
# Covington & Burling                                      2
# Sidley Austin LLP                                        2
# Google, Inc.                                             2
# University of Washington                                 2
# Microsoft                                                2
# Jones Day                                                2
#                                                       ...
# Geary Porter And Donovan                                 1
# Purdue University                                        1
# Baker Hostetler                                          1
# Inland Valley Infectious Disease Med Grp                 1
# EAG LLC                                                  1
# Navy (Retired)                                           1
# Seneca Strategy Partners, Inc.                           1
# Fox                                                      1
# World Bank Group: International Finance Corporation      1
# The Torrey Funds                                         1
# Presidio Pharmaceuticals                                 1
# Westec Corporation                                       1
# USIP                                                     1
# State Of Arizona                                         1
# Natural Health Technologies, Inc                         1
# Michael H. Berman, P.C.                                  1
# Frank's Fabrics, Inc.                                    1
# Virginia Commonwealth University Health System           1
# NOOR GROUP                                               1
# Florida A&M Univ. College of Law                         1
# KLA-Tencor Corp                                          1
# Brown University                                         1
# Better Life Communications                               1
# Dupage Medical Group                                     1
# Larry Bell Inc                                           1
# Murray Pacific                                           1
# AUD                                                      1
# Hirson,Inc                                               1
# Oswego Boces                                             1
# Foley And Lardner                                        1
# Name: Employer, Length: 1009, dtype: int64

# %%
df['Employer'] = df['Employer'].replace({'Not Employed': 'Unemployed'})
df['Employer'].value_counts()
# Out:
# Self-Employed                                          314
# None                                                   249
# Retired                                                126
# Unemployed                                               8
# Google                                                   6
# University of California                                 3
# Social Security Administration                           3
# Bank Of America                                          3
# University Hospital                                      2
# CSC                                                      2
# Newton Public Schools                                    2
# Quadrangle Group                                         2
# University Of Michigan                                   2
# Skadden, Arps                                            2
# University of Washington                                 2
# Kaiser Permanente                                        2
# Mayer Brown                                              2
# Davis Polk & Wardwell                                    2
# Ariel Investments                                        2
# Berger & Montague                                        2
# Hugo Neu Corporation                                     2
# Mayer Brown LLP                                          2
# United Health Group                                      2
# Covington & Burling                                      2
# Sidley Austin LLP                                        2
# Google, Inc.                                             2
# LMI                                                      2
# University of Michigan                                   2
# Jones Day                                                2
# Harvard University                                       2
#                                                       ...
# Baker Hostetler                                          1
# Reed Business Information                                1
# Inland Valley Infectious Disease Med Grp                 1
# EAG LLC                                                  1
# Navy (Retired)                                           1
# Seneca Strategy Partners, Inc.                           1
# Fox                                                      1
# World Bank Group: International Finance Corporation      1
# The Torrey Funds                                         1
# Presidio Pharmaceuticals                                 1
# Westec Corporation                                       1
# USIP                                                     1
# State Of Arizona                                         1
# Natural Health Technologies, Inc                         1
# Michael H. Berman, P.C.                                  1
# Frank's Fabrics, Inc.                                    1
# Virginia Commonwealth University Health System           1
# NOOR GROUP                                               1
# Florida A&M Univ. College of Law                         1
# KLA-Tencor Corp                                          1
# Brown University                                         1
# Better Life Communications                               1
# Dupage Medical Group                                     1
# Larry Bell Inc                                           1
# Murray Pacific                                           1
# AUD                                                      1
# Hirson,Inc                                               1
# Oswego Boces                                             1
# Purdue University                                        1
# Foley And Lardner                                        1
# Name: Employer, Length: 1008, dtype: int64

# %%
# Display a statistical overview
# We can infer the maximum allowable individual contribution from 'max'
df.describe()
# Out:
#             Amount
# count  1743.000000
# mean    640.124750
# std    1242.343265
# min       5.000000
# 25%     200.000000
# 50%     250.000000
# 75%     500.000000
# max    5000.000000

# %% [markdown]
# ## Students Work in Pairs Turn: Activity 4 Portland Crime
#
# ### Instructions
#
#   * Read in the csv using Pandas and print out the DataFrame that is returned
#
#   * Get a count of rows within the DataFrame in order to determine if there are any null values
#
#   * Drop the rows which contain null values
#
#   * Search through the "Offense Type" column and replace any similar values with one consistent value
#
#   * Create a couple DataFrames that look into one Neighborhood only and print them to the screen

# %%
# Import Dependencies
import pandas as pd

# %%
# Reference the file where the CSV is located
crime_csv_path = "Resources/crime_incident_data2017.csv"
# Import the data into a Pandas DataFrame
crime_df = pd.read_csv(crime_csv_path)
crime_df.head()
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses            1.0                                     Rape
# 1    Fraud Offenses            1.0                           Identity Theft
# 2    Fraud Offenses            1.0  False Pretenses/Swindle/Confidence Game
# 3    Fraud Offenses            1.0                           Identity Theft
# 4  Larceny Offenses            1.0                        All Other Larceny
#
#    Open Data Lat  Open Data Lon  Open Data X  Open Data Y Report Date  \
# 0            NaN            NaN          NaN          NaN     1/26/17
# 1            NaN            NaN          NaN          NaN     1/20/17
# 2        45.5207       -122.583    7668150.0     682825.0      1/9/17
# 3            NaN            NaN          NaN          NaN      1/5/17
# 4            NaN            NaN          NaN          NaN      1/5/17
#
#   Report Month Year
# 0            1/1/17
# 1            1/1/17
# 2            1/1/17
# 3            1/1/17
# 4            1/1/17

# %%
# look for missing values
crime_df.count()
# Out:
# Address              6456
# Case Number          7060
# Crime Against        7060
# Neighborhood         6865
# Number of Records    7060
# Occur Date           7060
# Occur Month Year     7060
# Occur Time           7060
# Offense Category     7060
# Offense Count        7059
# Offense Type         7059
# Open Data Lat        6348
# Open Data Lon        6348
# Open Data X          6348
# Open Data Y          6348
# Report Date          7059
# Report Month Year    7059
# dtype: int64

# %%
# drop null rows
no_null_crime_df = crime_df.dropna(how="any")

# %%
# verify counts
no_null_crime_df.count()
# Out:
# Address              6272
# Case Number          6272
# Crime Against        6272
# Neighborhood         6272
# Number of Records    6272
# Occur Date           6272
# Occur Month Year     6272
# Occur Time           6272
# Offense Category     6272
# Offense Count        6272
# Offense Type         6272
# Open Data Lat        6272
# Open Data Lon        6272
# Open Data X          6272
# Open Data Y          6272
# Report Date          6272
# Report Month Year    6272
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
no_null_crime_df["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       1157
# Motor Vehicle Theft                             977
# All Other Larceny                               751
# Vandalism                                       559
# Burglary                                        510
# Shoplifting                                     460
# Identity Theft                                  333
# Simple Assault                                  198
# Theft of Motor Vehicle Parts or Accessories     172
# False Pretenses/Swindle/Confidence Game         166
# Drug/Narcotic Violations                        150
# Intimidation                                    148
# Theft From Building                             148
# Aggravated Assault                              131
# Robbery                                         114
# Counterfeiting/Forgery                          104
# Credit Card/ATM Fraud                            38
# Weapons Law Violations                           37
# Prostitution                                     36
# Arson                                            19
# Embezzlement                                     17
# Purse-Snatching                                  14
# Pocket-Picking                                   11
# Stolen Property Offenses                          9
# Theft From Coin-Operated Machine or Device        5
# Hacking/Computer Invasion                         4
# Extortion/Blackmail                               1
# Drug Equipment Violations                         1
# Kidnapping/Abduction                              1
# Pornography/Obscene Material                      1
# Name: Offense Type, dtype: int64

# %%
# Combine similar offenses
no_null_crime_df["Offense Type"] = no_null_crime_df["Offense Type"].replace(
{"Commercial Sex Acts": "Prostitution", "Assiting or Promoting Prostitution": "Prostitution"})
no_null_crime_df
# Out:
# C:\Users\drew\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                               Address Case Number Crime Against  \
# 2            200 BLOCK OF SE 78TH AVE   17-900367      Property
# 5        5400 BLOCK OF NE MALLORY AVE   17-900129      Property
# 6           5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 7           5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 8           12000 BLOCK OF SE PINE ST   17-900253      Property
# 9           12000 BLOCK OF SE PINE ST   17-900253      Property
# 10        12200 BLOCK OF N JANTZEN DR    17-11435      Property
# 11          1600 BLOCK OF NE 148TH PL   17-901114      Property
# 12      12800 BLOCK OF NE AIRPORT WAY    17-30672      Property
# 15          800 BLOCK OF N WEBSTER ST   17-901179      Property
# 16         1200 BLOCK OF LLOYD CENTER   17-900552      Property
# 7054                Lloyd                  1    2/15/17           2/1/17
# 7055                Lloyd                  1    2/15/17           2/1/17
# 7056              Russell                  1    2/15/17           2/1/17
# 7057             St Johns                  1    2/15/17           2/1/17
# 7058            Sunnyside                  1    2/15/17           2/1/17
#
#       Occur Time        Offense Category  Offense Count  \
# 2            800          Fraud Offenses            1.0
# 5           1612          Fraud Offenses            1.0
# 6           1200          Fraud Offenses            1.0
# 7           1200          Fraud Offenses            1.0
# 8            805          Fraud Offenses            1.0
# 9            805          Fraud Offenses            1.0
# 10           900          Fraud Offenses            1.0
# 11          1120          Fraud Offenses            1.0
# 12             0            Embezzlement            1.0
# 15          1620          Fraud Offenses            1.0
# 16          2357        Larceny Offenses            1.0
# 17          1500        Larceny Offenses            1.0
# 18           100        Larceny Offenses            1.0
# 19           935          Fraud Offenses            1.0
# 20          1040          Fraud Offenses            1.0
# 21          2200        Larceny Offenses            1.0
# 22            30        Larceny Offenses            1.0
# 23          2200        Larceny Offenses            1.0
# 24          1250          Fraud Offenses            1.0
# 25          1250          Fraud Offenses            1.0
# 26          1550          Fraud Offenses            1.0
# 27          1550          Fraud Offenses            1.0
# 30             0          Fraud Offenses            1.0
# 31          1530        Larceny Offenses            1.0
# 32          2300        Larceny Offenses            1.0
# 33          1900     Motor Vehicle Theft            1.0
# 34          1600                Burglary            1.0
# 35           815        Larceny Offenses            1.0
# 36          1900        Larceny Offenses            1.0
# 37          1900     Motor Vehicle Theft            1.0
# ...          ...                     ...            ...
# 7025        1815                Burglary            1.0
# 7026         645                Burglary            1.0
# 7027         946                Burglary            1.0
# 7028         841  Counterfeiting/Forgery            1.0
# 7029        2138  Counterfeiting/Forgery            1.0
# 7030        2305  Counterfeiting/Forgery            1.0
# 7032        1200          Fraud Offenses            1.0
# 7033         528          Fraud Offenses            1.0
# 7034        1436          Fraud Offenses            1.0
# 7035         926          Fraud Offenses            1.0
# 7036        1200          Fraud Offenses            1.0
# 7038        1200          Fraud Offenses            1.0
# 7039        1139          Fraud Offenses            1.0
# 7041        1827        Larceny Offenses            1.0
# 7042         855        Larceny Offenses            1.0
# 7043        1445        Larceny Offenses            1.0
# 7044        1410        Larceny Offenses            1.0
# 7046        1544        Larceny Offenses            1.0
# 7047        1800        Larceny Offenses            1.0
# 7048        1545        Larceny Offenses            1.0
# 7049        1647        Larceny Offenses            1.0
# 7050        1334        Larceny Offenses            1.0
# 7051        1430        Larceny Offenses            1.0
# 7052         935        Larceny Offenses            1.0
# 7053        1830        Larceny Offenses            1.0
# 7054        1300        Larceny Offenses            1.0
# 7055        1832        Larceny Offenses            1.0
# 7056        1958        Larceny Offenses            1.0
# 7057         836        Larceny Offenses            1.0
# 7058        1222        Larceny Offenses            1.0
#
#                                      Offense Type  Open Data Lat  \
# 2         False Pretenses/Swindle/Confidence Game        45.5207
# 5                                  Identity Theft        45.5625
# 6         False Pretenses/Swindle/Confidence Game        45.5594
# 7                                  Identity Theft        45.5594
# 8                           Credit Card/ATM Fraud        45.5204
# 9                                  Identity Theft        45.5204
# 10                                 Identity Theft        45.6116
# 11                                 Identity Theft        45.5352
# 12                                   Embezzlement        45.5639
# 15                                 Identity Theft        45.5598
# 16                                    Shoplifting        45.5323
# 17                              All Other Larceny        45.5049
# 18                              All Other Larceny        45.5820
# 19                                 Identity Theft        45.5642
# 20                                 Identity Theft        45.5272
# 21                       Theft From Motor Vehicle        45.5270
# 22                       Theft From Motor Vehicle        45.5595
# 23                              All Other Larceny        45.5499
# 24                          Credit Card/ATM Fraud        45.5017
# 25                                 Identity Theft        45.5017
# 26        False Pretenses/Swindle/Confidence Game        45.5279
# 27                                 Identity Theft        45.5279
# 30                                 Identity Theft        45.5978
# 31                       Theft From Motor Vehicle        45.6098
# 32                       Theft From Motor Vehicle        45.5217
# 33                            Motor Vehicle Theft        45.5223
# 34                                       Burglary        45.4558
# 35                       Theft From Motor Vehicle        45.5232
# 36    Theft of Motor Vehicle Parts or Accessories        45.4906
# 37                            Motor Vehicle Theft        45.4906
# ...                                           ...            ...
# 7025                                     Burglary        45.5230
# 7026                                     Burglary        45.4982
# 7027                                     Burglary        45.5348
# 7028                       Counterfeiting/Forgery        45.5351
# 7029                       Counterfeiting/Forgery        45.5233
# 7030                       Counterfeiting/Forgery        45.5165
# 7032      False Pretenses/Swindle/Confidence Game        45.4916
# 7033      False Pretenses/Swindle/Confidence Game        45.4868
# 7034      False Pretenses/Swindle/Confidence Game        45.5106
# 7035      False Pretenses/Swindle/Confidence Game        45.6038
# 7036      False Pretenses/Swindle/Confidence Game        45.5323
# 7038                               Identity Theft        45.4916
# 7039                               Identity Theft        45.5308
# 7041                            All Other Larceny        45.5166
# 7042                            All Other Larceny        45.5320
# 7043                            All Other Larceny        45.5413
# 7044                            All Other Larceny        45.5591
# 7046                                  Shoplifting        45.5042
# 7047                                  Shoplifting        45.5199
# 7048                                  Shoplifting        45.5310
# 7049                                  Shoplifting        45.5310
# 7050                                  Shoplifting        45.5335
# 7051                                  Shoplifting        45.5183
# 7052                                  Shoplifting        45.5048
# 7053                                  Shoplifting        45.5305
# 7054                                  Shoplifting        45.5325
# 7055                                  Shoplifting        45.5320
# 7056                                  Shoplifting        45.5368
# 7057                                  Shoplifting        45.5930
# 7058                                  Shoplifting        45.5121
#
#       Open Data Lon  Open Data X  Open Data Y Report Date Report Month Year
# 2          -122.583    7668150.0     682825.0      1/9/17            1/1/17
# 5          -122.664    7647987.0     698581.0      1/3/17            1/1/17
# 6          -122.646    7652567.0     697337.0     1/26/17            1/1/17
# 7          -122.646    7652567.0     697337.0     1/26/17            1/1/17
# 8          -122.539    7679522.0     682404.0      1/6/17            1/1/17
# 9          -122.539    7679522.0     682404.0      1/6/17            1/1/17
# 10         -122.676    7645287.0     716588.0     1/12/17            1/1/17
# 11         -122.508    7687592.0     687631.0     1/27/17            1/1/17
# 12         -122.530    7682294.0     698212.0     1/31/17            1/1/17
# 15         -122.676    7644953.0     697679.0     1/28/17            1/1/17
# 16         -122.655    7650030.0     687510.0     1/14/17            1/1/17
# 17         -122.643    7652722.0     677445.0     1/24/17            1/1/17
# 18         -122.687    7642273.0     705875.0     1/30/17            1/1/17
# [6272 rows x 17 columns]

# %%
# Create a new DataFrame that looks into a specific neighborhood
vernon_crime_df = no_null_crime_df.loc[no_null_crime_df["Neighborhood"] == "Vernon"]
vernon_crime_df
# Out:
#                                 Address Case Number Crime Against  \
# 6             5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 7             5000 BLOCK OF NE 19TH AVE   17-901079      Property
# 147         1000 BLOCK OF NE EMERSON ST   17-901190      Property
# 148         1000 BLOCK OF NE EMERSON ST   17-901190      Property
# 271            5300 BLOCK OF NE 14TH PL     17-2593      Property
# 572           5400 BLOCK OF NE 13TH AVE   17-900012      Property
# 742           5700 BLOCK OF NE 12TH AVE     17-2395      Property
# 862           5100 BLOCK OF NE 17TH AVE   17-900165      Property
# 1243        1800 BLOCK OF NE ALBERTA ST   17-900302      Property
# 1531  1500 BLOCK OF NE KILLINGSWORTH ST     17-8822      Property
# 1696  1600 BLOCK OF NE KILLINGSWORTH ST   17-900456      Property
# 1733          5700 BLOCK OF NE 16TH AVE   17-900435      Property
# 2102        2100 BLOCK OF NE ALBERTA ST    17-15011      Property
# 2391      1400 BLOCK OF NE AINSWORTH ST    17-16910      Property
# 2502      1400 BLOCK OF NE AINSWORTH ST   17-900741      Property
# 2547      1400 BLOCK OF NE AINSWORTH ST   17-900713      Property
# 2911        1800 BLOCK OF NE ALBERTA ST    17-19949      Property
# 3154          5300 BLOCK OF NE 17TH AVE    17-22029        Person
# 3282        1600 BLOCK OF NE ALBERTA ST    17-23090      Property
# 3632          4800 BLOCK OF NE 15TH AVE    17-25218      Property
# 4154          4900 BLOCK OF NE 19TH AVE    17-29524      Property
# 4155          4900 BLOCK OF NE 19TH AVE    17-29524      Property
# 4569          5800 BLOCK OF NE 11TH AVE   17-902084      Property
# 4640          5300 BLOCK OF NE 17TH AVE    17-33094        Person
# 4646          5400 BLOCK OF NE 15TH AVE   17-901513      Property
# 5523           4900 BLOCK OF NE 14TH PL    17-36314        Person
# 5750          5000 BLOCK OF NE 17TH AVE    17-37871      Property
# 7044        2000 BLOCK OF NE ALBERTA ST   17-902047      Property
#
#      Neighborhood  Number of Records Occur Date Occur Month Year  Occur Time  \
# 6          Vernon                  1    11/8/13          11/1/13        1200
# 7          Vernon                  1    11/8/13          11/1/13        1200
# 147        Vernon                  1   11/26/16          11/1/16        2040
# 148        Vernon                  1   11/26/16          11/1/16        2040
# 271        Vernon                  1   12/19/16          12/1/16         900
# 572        Vernon                  1     1/1/17           1/1/17         725
# 742        Vernon                  1     1/2/17           1/1/17        2000
# 862        Vernon                  1     1/3/17           1/1/17        2230
# 1243       Vernon                  1     1/6/17           1/1/17        1300
# 1531       Vernon                  1     1/9/17           1/1/17        2345
# 1696       Vernon                  1     1/5/17           1/1/17        2030
# 1733       Vernon                  1    1/11/17           1/1/17         300
# 2102       Vernon                  1    1/15/17           1/1/17        2236
# 2391       Vernon                  1    1/16/17           1/1/17        2130
# 2502       Vernon                  1     1/4/17           1/1/17        1330
# 2547       Vernon                  1    1/18/17           1/1/17        2125
# 2911       Vernon                  1    1/21/17           1/1/17        1403
# 3154       Vernon                  1    1/23/17           1/1/17        1000
# 3282       Vernon                  1    1/23/17           1/1/17        1830
# 3632       Vernon                  1    1/26/17           1/1/17        1220
# 4154       Vernon                  1    1/23/17           1/1/17        1200
# 4155       Vernon                  1    1/23/17           1/1/17        1200
# 4569       Vernon                  1    12/8/15          12/1/15           0
# 4640       Vernon                  1    12/9/16          12/1/16        1700
# 4646       Vernon                  1   12/23/16          12/1/16        1400
# 5523       Vernon                  1     2/5/17           2/1/17        2100
# 5750       Vernon                  1     2/4/17           2/1/17        1200
# 7044       Vernon                  1    2/15/17           2/1/17        1410
#
#               Offense Category  Offense Count  \
# 6               Fraud Offenses            1.0
# 7               Fraud Offenses            1.0
# 147             Fraud Offenses            1.0
# 148           Larceny Offenses            1.0
# 271           Larceny Offenses            1.0
# 572           Larceny Offenses            1.0
# 742                  Vandalism            1.0
# 862           Larceny Offenses            1.0
# 1243          Larceny Offenses            1.0
# 1531          Larceny Offenses            1.0
# 1696          Larceny Offenses            1.0
# 1733          Larceny Offenses            1.0
# 2102    Counterfeiting/Forgery            1.0
# 2391       Motor Vehicle Theft            1.0
# 2502          Larceny Offenses            1.0
# 2547          Larceny Offenses            1.0
# 2911  Stolen Property Offenses            1.0
# 3154          Assault Offenses            1.0
# 3282            Fraud Offenses            1.0
# 3632          Larceny Offenses            1.0
# 4154            Fraud Offenses            1.0
# 4155            Fraud Offenses            1.0
# 4569          Larceny Offenses            1.0
# 4640          Assault Offenses            1.0
# 4646          Larceny Offenses            1.0
# 5523          Assault Offenses            1.0
# 5750          Larceny Offenses            1.0
# 7044          Larceny Offenses            1.0
#
#                                  Offense Type  Open Data Lat  Open Data Lon  \
# 6     False Pretenses/Swindle/Confidence Game        45.5594       -122.646
# 7                              Identity Theft        45.5594       -122.646
# 147                            Identity Theft        45.5619       -122.655
# 148                         All Other Larceny        45.5619       -122.655
# 271                         All Other Larceny        45.5618       -122.651
# 572                  Theft From Motor Vehicle        45.5625       -122.652
# 742                                 Vandalism        45.5643       -122.653
# 862                  Theft From Motor Vehicle        45.5600       -122.648
# 1243                      Theft From Building        45.5590       -122.646
# 1531                              Shoplifting        45.5627       -122.649
# 1696                        All Other Larceny        45.5627       -122.648
# 1733                        All Other Larceny        45.5642       -122.649
# 2102                   Counterfeiting/Forgery        45.5590       -122.643
# 2391                      Motor Vehicle Theft        45.5662       -122.651
# 2502                        All Other Larceny        45.5662       -122.651
# 2547                 Theft From Motor Vehicle        45.5662       -122.651
# 2911                 Stolen Property Offenses        45.5590       -122.646
# 3154                           Simple Assault        45.5619       -122.648
# 3282                    Credit Card/ATM Fraud        45.5591       -122.648
# 3632                        All Other Larceny        45.5581       -122.650
# 4154                    Credit Card/ATM Fraud        45.5587       -122.646
# 4155                           Identity Theft        45.5587       -122.646
# 4569                        All Other Larceny        45.5650       -122.654
# 4640                             Intimidation        45.5619       -122.648
# 4646                        All Other Larceny        45.5625       -122.650
# 5523                           Simple Assault        45.5588       -122.651
# 5750                           Pocket-Picking        45.5594       -122.648
# 7044                        All Other Larceny        45.5591       -122.644
#
#       Open Data X  Open Data Y Report Date Report Month Year
# 6       7652567.0     697337.0     1/26/17            1/1/17
# 7       7652567.0     697337.0     1/26/17            1/1/17
# 147     7650320.0     698297.0     1/29/17            1/1/17
# 148     7650320.0     698297.0     1/29/17            1/1/17
# 271     7651314.0     698264.0      1/3/17            1/1/17
# 572     7650993.0     698515.0      1/1/17            1/1/17
# 742     7650716.0     699162.0      1/3/17            1/1/17
# 862     7652075.0     697582.0      1/4/17            1/1/17
# 1243    7652422.0     697213.0      1/7/17            1/1/17
# 1531    7651670.0     698560.0      1/9/17            1/1/17
# 1696    7651925.0     698552.0     1/11/17            1/1/17
# 1733    7651785.0     699124.0     1/11/17            1/1/17
# 2102    7653171.0     697189.0     1/15/17            1/1/17
# 2391    7651404.0     699868.0     1/18/17            1/1/17
# 2502    7651404.0     699868.0     1/19/17            1/1/17
# 2547    7651404.0     699868.0     1/19/17            1/1/17
# 2911    7652422.0     697213.0     1/21/17            1/1/17
# 3154    7652096.0     698253.0     1/23/17            1/1/17
# 3282    7651923.0     697261.0     1/24/17            1/1/17
# 3632    7651520.0     696878.0     1/26/17            1/1/17
# 4154    7652527.0     697100.0     1/30/17            1/1/17
# 4155    7652527.0     697100.0     1/30/17            1/1/17
# 4569    7650467.0     699447.0     2/16/17            2/1/17
# 4640    7652096.0     698253.0      2/2/17            2/1/17
# 4646    7651603.0     698481.0      2/3/17            2/1/17
# 5523    7651310.0     697139.0      2/5/17            2/1/17
# 5750    7652067.0     697353.0      2/7/17            2/1/17
# 7044    7652922.0     697229.0     2/15/17            2/1/17

# %% [markdown]
# ## Everyone Turn: Activity 5 Pandas Recap

# %%
# Import the Pandas library
import pandas as pd

# %%
# Create a reference the CSV file desired
csv_path = "Resources/ufoSightings.csv"

# Read the CSV into a Pandas DataFrame
ufo_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
ufo_df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008  53.200000
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.418056
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
# Check to see if there are any rows with missing data
ufo_df.count()
# Out:
# datetime                6465
# city                    6464
# state                   6124
# country                 5760
# shape                   6345
# duration (seconds)      6464
# duration (hours/min)    6464
# comments                6463
# date posted             6464
# latitude                6464
# longitude               6464
# dtype: int64

# %%
# Remove the rows with missing data
clean_ufo_df = ufo_df.dropna(how="any")
clean_ufo_df.count()
# Out:
# datetime                5512
# city                    5512
# state                   5512
# country                 5512
# shape                   5512
# duration (seconds)      5512
# duration (hours/min)    5512
# comments                5512
# date posted             5512
# latitude                5512
# longitude               5512
# dtype: int64

# %%
# Filter the data so that only those sightings in the US are in a DataFrame
usa_ufo_df = clean_ufo_df.loc[clean_ufo_df["country"] == "us", :]
usa_ufo_df
# Out:
#               datetime                               city state country  \
# 0     10/10/1949 20:30                         san marcos    tx      us
# 3     10/10/1956 21:00                               edna    tx      us
# 4     10/10/1960 20:00                            kaneohe    hi      us
# 5     10/10/1961 19:00                            bristol    tn      us
# 7     10/10/1965 23:45                            norwalk    ct      us
# 8     10/10/1966 20:00                          pell city    al      us
# 9     10/10/1966 21:00                           live oak    fl      us
# 10    10/10/1968 13:00                          hawthorne    ca      us
# 12         disk              1800.0              30 min.
# 13      unknown               180.0            3 minutes
# 14         oval                30.0           30 seconds
# 15       circle              1200.0            20minutes
# 16         disk               120.0            2 minutes
# 17         disk              1800.0            20-30 min
# 19        other              2700.0           45 minutes
# 21        light              1200.0            one hour?
# 22        light               360.0          5-6 minutes
# 23         oval                60.0             1 minute
# 25        other                30.0           30 seconds
# 26        light                30.0   approx: 30 seconds
# 27    rectangle               300.0                 5min
# 28      chevron               900.0           15 minutes
# 30         oval               180.0            3 minutes
# 31      unknown              1800.0              30mins.
# 32       sphere               180.0                3 min
# 33      unknown               300.0            5 minutes
# 34        light               300.0           3 to 5 min
# 36       circle                60.0             1 minute
# 37        other               120.0       couple minutes
# ...         ...                 ...                  ...
# 6428      light               120.0            2 minutes
# 6429   fireball                10.0  at least 10 seconds
# 6430  formation               480.0       5 to 8 minutes
# 6431     sphere               900.0               15 min
# 6432     sphere                 4.0          3-4 seconds
# 6433     circle               240.0          4 minutes +
# 6436   triangle                 5.0            5 seconds
# 6437      other                30.0           30 seconds
# 6438    chevron               120.0          1-2 minutes
# 6439   triangle                 5.0          < 5 seconds
# 6441      other              1200.0        15-20 minutes
# 6442   triangle               300.0         five minutes
# 6443   changing             14400.0                4hrs.
# 6444    unknown                10.0           10 seconds
# 6445     circle               120.0            2 minutes
# 6446   fireball                30.0            30seconds
# 6447   fireball               600.0               10 min
# 6448     circle               900.0           15 minutes
# 6449  rectangle               600.0              10 mins
# 6450     circle               900.0            10-15 min
# 6451       oval                20.0              20 sec.
# 6452     circle                15.0        10-15 seconds
# 6453      light               300.0            5 minutes
# 6454      light                10.0         5-10 seconds
# 6455      light                20.0           20 seconds
# 6456   fireball                 6.0            6 seconds
# 6458      cross                 2.0              seconds
# 6460   triangle               900.0           15 minutes
# 6461   fireball               600.0              10 min.
# 6462  formation                12.0           12 seconds
#
#                                                comments date posted  \
# 0     This event took place in early fall around 194...   4/27/2004
# 3     My older brother and twin sister were leaving ...   1/17/2004
# 4     AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 5     My father is now 89 my brother 52 the girl wit...   4/27/2007
# 7     A bright orange color changing to reddish colo...   10/2/1999
# 8     Strobe Lighted disk shape object observed clos...   3/19/2009
# 9     Saucer zaps energy from powerline as my pregna...   5/11/2005
# 10    ROUND &#44 ORANGE &#44 WITH WHAT I WOULD SAY W...  10/31/2003
# 11    silent red /orange mass of energy floated by t...   6/12/2008
# 12             silver disc seen by family and neighbors   5/11/2000
# 13    Slow moving&#44 silent craft accelerated at an...   2/14/2008
# 14    green oval shaped light over my local church&#...   2/14/2010
# 15    On october 10&#44 1972 myself&#44my 5yrs.daugh...   9/15/2005
# 16    The UFO was so close&#44 my battery in the car...   8/14/2007
# 17    Oh&#44 what a night &#33  Two (2) saucer-shape...   9/24/2003
# 19    Not sure of the eact month or year of this sig...   8/10/1999
# 21                                 The light chased us.   7/25/2004
# 22    Several Flashing UFO lights over Charleston Na...   2/14/2008
# 23    Three extremely large lights hanging above nea...    2/7/2014
# 25    i was about six or seven and my family and me ...   2/24/2005
# 26    HBCCUFO CANADIAN REPORT:  Pilot Sighting Of Un...   3/17/2004
# 25    29.423889  -98.493333
# 26    38.254167  -85.759444
# 27    40.700833  -73.713333
# 28    41.700278  -73.921389
# 30    32.715278 -117.156389
# 31    38.758333 -104.742500
# 32    29.763056  -95.363056
# 33    32.783333  -96.800000
# 34    42.995556  -71.455278
# 36    29.763056  -95.363056
# 37    44.763056  -85.620556
# ...         ...         ...
# 6428  43.100833  -75.233056
# 6429  33.466944 -117.697222
# 6430  29.763056  -95.363056
# 6431  34.257222 -118.466111
# 6432  34.384722 -118.530000
# 6433  27.947222  -82.458611
# 6436  44.739444  -93.125556
# 6437  36.818889  -76.275278
# 6438  29.763056  -95.363056
# 6439  32.221667 -110.925833
# 6441  47.913056 -122.096944
# 6442  38.833889 -104.820833
# 6443  34.748889 -112.113056
# 6444  46.211389 -119.136111
# 6445  30.603333  -87.903611
# 6446  42.637500  -70.950000
# 6447  47.322500 -122.311389
# 6448  40.233889 -111.657778
# 6449  24.555278  -81.782778
# 6450  36.908611 -111.472778
# 6451  37.836111  -87.590000
# 6452  33.688889  -78.886944
# 6453  39.161111  -89.493611
# 6454  34.052222 -118.242778
# 6455  32.912500  -96.638611
# 6456  45.638889 -122.660278
# 6458  46.783333  -92.106389
# 6460  42.033333  -87.883333
# 6461  33.493611 -117.147500
# 6462  38.352778 -120.931667
#
# [5334 rows x 11 columns]

# %%
# Count how many sightings have occured within each state
state_counts = usa_ufo_df["state"].value_counts()
state_counts
# Out:
# ca    629
# tx    353
# wa    295
# fl    276
# ny    245
# il    240
# oh    203
# pa    197
# az    191
# nc    175
# co    138
# mi    132
# or    128
# tn    124
# mo    121
# va    120
# in    106
# ga    103
# wi     95
# sc     95
# ma     85
# mn     79
# nj     76
# ky     75
# md     74
# nv     68
# ct     67
# ok     65
# ar     60
# nm     60
# ia     57
# al     57
# ut     56
# ks     55
# me     44
# nh     44
# la     41
# id     37
# ms     35
# mt     35
# wv     33
# ak     32
# ne     27
# hi     20
# vt     18
# sd     17
# ri     17
# wy     16
# de     11
# nd      6
# pr      1
# Name: state, dtype: int64

# %%
# Convert the state_counts Series into a DataFrame
state_ufo_counts_df = pd.DataFrame(state_counts)
state_ufo_counts_df.head()
# Out:
#     state
# ca    629
# tx    353
# wa    295
# fl    276
# ny    245

# %%
# Convert the column name into "Sum of Sightings"
state_ufo_counts_df = state_ufo_counts_df.rename(
    columns={"state": "Sum of Sightings"})
state_ufo_counts_df.head()
# Out:
#     Sum of Sightings
# ca               629
# tx               353
# wa               295
# fl               276
# ny               245

# %%
# Want to add up the seconds UFOs are seen? There is a problem
# Problem can be seen by examining datatypes within the DataFrame
usa_ufo_df.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)      float64
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                float64
# longitude               float64
# dtype: object

# %%
# Using to_numeric() to convert a column's data into floats
usa_ufo_df["duration (seconds)"] = pd.to_numeric(
    usa_ufo_df["duration (seconds)"])
usa_ufo_df.dtypes
# Out:
# C:\Users\drew\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)      float64
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                float64
# longitude               float64
# dtype: object

# %%
# Now it is possible to find the sum of seconds
usa_ufo_df["duration (seconds)"].sum()
# Out:
# 9021339.65

# %% [markdown]
# ## Instructor Turn: Activity 6 Group By

# %%
# Import Dependencies
import pandas as pd

# %%
# Create a reference the CSV file desired
csv_path = "Resources/ufoSightings.csv"

# Read the CSV into a Pandas DataFrame
ufo_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
ufo_df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008  53.200000
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.418056
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
# Remove the rows with missing data
clean_ufo_df = ufo_df.dropna(how="any")
clean_ufo_df.count()
# Out:
# datetime                5512
# city                    5512
# state                   5512
# country                 5512
# shape                   5512
# duration (seconds)      5512
# duration (hours/min)    5512
# comments                5512
# date posted             5512
# latitude                5512
# longitude               5512
# dtype: int64

# %%
# Converting the "duration (seconds)" column's values to numeric
clean_ufo_df["duration (seconds)"] = pd.to_numeric(
    clean_ufo_df["duration (seconds)"])
# Out:
# C:\Users\drew\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Filter the data so that only those sightings in the US are in a DataFrame
usa_ufo_df = clean_ufo_df.loc[clean_ufo_df["country"] == "us", :]

usa_ufo_df.head()
# Out:
#            datetime        city state country     shape  duration (seconds)  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700.0
# 3  10/10/1956 21:00        edna    tx      us    circle                20.0
# 4  10/10/1960 20:00     kaneohe    hi      us     light               900.0
# 5  10/10/1961 19:00     bristol    tn      us    sphere               300.0
# 7  10/10/1965 23:45     norwalk    ct      us      disk              1200.0
#
#   duration (hours/min)                                           comments  \
# 0           45 minutes  This event took place in early fall around 194...
# 3             1/2 hour  My older brother and twin sister were leaving ...
# 4           15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5            5 minutes  My father is now 89 my brother 52 the girl wit...
# 7           20 minutes  A bright orange color changing to reddish colo...
#
#   date posted   latitude  longitude
# 0   4/27/2004  29.883056  -97.941111
# 3   1/17/2004  28.978333  -96.645833
# 4   1/22/2004  21.418056 -157.803611
# 5   4/27/2007  36.595000  -82.188889
# 7   10/2/1999  41.117500  -73.408333

# %%
# Count how many sightings have occured within each state
state_counts = usa_ufo_df["state"].value_counts()
state_counts.head()
# Out:
# ca    629
# tx    353
# wa    295
# fl    276
# ny    245
# Name: state, dtype: int64

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_usa_df = usa_ufo_df.groupby(['state'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_usa_df)

# In order to be visualized, a data function must be used...
grouped_usa_df.count().head(10)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x0000015EC039B390>
#        datetime  city  country  shape  duration (seconds)  \
# state
# ak           32    32       32     32                  32
# al           57    57       57     57                  57
# ar           60    60       60     60                  60
# az          191   191      191    191                 191
# ca          629   629      629    629                 629
# co          138   138      138    138                 138
# ct           67    67       67     67                  67
# de           11    11       11     11                  11
# fl          276   276      276    276                 276
# ga          103   103      103    103                 103
#
#        duration (hours/min)  comments  date posted  latitude  longitude
# state
# ak                       32        32           32        32          32
# al                       57        57           57        57          57
# ar                       60        60           60        60          60
# az                      191       191          191       191         191
# ca                      629       629          629       629         629
# co                      138       138          138       138         138
# ct                       67        67           67        67          67
# de                       11        11           11        11          11
# fl                      276       276          276       276         276
# ga                      103       103          103       103         103

# %%
# Since "duration (seconds)" was converted to a numeric time, it can now be summed up per state
state_duration = grouped_usa_df["duration (seconds)"].sum()
state_duration.head()
# Out:
# state
# ak     67915.0
# al     40713.0
# ar    233053.0
# az    365206.1
# ca    460920.1
# Name: duration (seconds), dtype: float64

# %%
# Creating a new DataFrame using both duration and count
state_summary_table = pd.DataFrame({"Number of Sightings": state_counts,
                                    "Total Visit Time": state_duration})
state_summary_table.head()
# Out:
#     Number of Sightings  Total Visit Time
# ak                   32           67915.0
# al                   57           40713.0
# ar                   60          233053.0
# az                  191          365206.1
# ca                  629          460920.1

# %%
# It is also possible to group a DataFrame by multiple columns
# This returns an object with multiple indexes, however, which can be harder to deal with
grouped_international_data = clean_ufo_df.groupby(['country', 'state'])

# Converting a GroupBy object into a DataFrame
international_duration = pd.DataFrame(
    grouped_international_data["duration (seconds)"].sum())
international_duration.head(10)
# Out:
#                duration (seconds)
# country state
# au      nt                   60.0
#         wa                   30.0
# ca      ab                 5137.0
#         bc                25612.0
#         mb                42150.0
#         nb                 8940.0
#         nf                 7205.0
#         ns                  645.0
#         on                68052.0
#         pq                 4397.0

# %% [markdown]
# ##  Students Work in Pairs Turn: Activity 7 Building a Pokèdex
#
# ### Instructions
#
#   * Read the Pokemon CSV file with Pandas.
#
#   * Create a new table by extracting the following columns: "Type 1", "HP", "Attack", "Sp. Atk", "Sp. Def", and "Speed".
#
#   * Find the average stats for each type of Pokemon.
#
#   * Create a new DataFrame out of the averages.
#
#   * Calculate the total power level of each type of Pokemon by adding all of the previous stats together and place the results into a new column.
#
# ### Bonus
#
#   * Sort the table by strongest type and export the resulting table to a new CSV

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# File to load Save file path to variable
pokemon = "Resources/Pokemon.csv"

# %%
# Read with Pandas
pokemon_pd = pd.read_csv(pokemon)
pokemon_pd.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Extract the following columns: "Type 1", "HP", "Attack", "Sp. Atk", "Sp. Def", and "Speed"
pokemon_type = pokemon_pd[["Type 1", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]
pokemon_type.head()
# Out:
#   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  Grass  45      49       49       65       65     45
# 1  Grass  60      62       63       80       80     60
# 2  Grass  80      82       83      100      100     80
# 3  Grass  80     100      123      122      120     80
# 4   Fire  39      52       43       60       50     65

# %%
# Create the GroupBy object based on the "Type 1" column
pokemon_group = pokemon_type.groupby(["Type 1"])
# Calculate averages for combat stats using the .mean() method
pokemon_comparison = pokemon_group.mean()
pokemon_comparison
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type 1
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778   65.925926  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# Ice       72.000000   72.750000   71.416667  77.541667  76.291667   63.458333
# Normal    77.275510   73.469388   59.846939  55.816327  63.724490   71.551020
# Poison    67.250000   74.678571   68.821429  60.428571  64.392857   63.571429
# Psychic   70.631579   71.456140   67.684211  98.403509  86.280702   81.491228
# Rock      65.363636   92.863636  100.795455  63.340909  75.477273   55.909091
# Steel     65.222222   92.703704  126.370370  67.518519  80.629630   55.259259
# Water     72.062500   74.151786   72.946429  74.812500  70.517857   65.964286

# %%
# Total number of points
pokemon_comparison["Total"] = pokemon_comparison["HP"] + pokemon_comparison["Attack"] + pokemon_comparison["Defense"] + \
pokemon_comparison["Sp. Atk"] + \
pokemon_comparison["Sp. Def"] + pokemon_comparison["Speed"]

pokemon_comparison["Total"]
# Out:
# Type 1
# Bug         378.927536
# Dark        445.741935
# Dragon      550.531250
# Electric    443.409091
# Fairy       413.176471
# Fighting    416.444444
# Fire        458.076923
# Flying      485.000000
# Ghost       439.562500
# Grass       421.142857
# Ground      437.500000
# Ice         433.458333
# Normal      401.683673
# Poison      399.142857
# Psychic     475.947368
# Rock        453.750000
# Steel       487.703704
# Water       430.455357
# Name: Total, dtype: float64

# %%
# Bonus: Sort the table by strongest type and export the resulting table to a new CSV.
strongest_pokemon = pokemon_comparison.sort_values(["Total"], ascending=False)
strongest_pokemon.reset_index(inplace=True)
strongest_pokemon
pokemon_comparison.to_excel("output/pokemon_rankings.xlsx", index=False)

# %% [markdown]
# ## Instructor Turn: Activity 8 Sorting

# %%
# Import Dependencies
import pandas as pd

# %%
csv_path = "Resources/Happiness_2017.csv"
happiness_df = pd.read_csv(csv_path)
happiness_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
# Sorting the DataFrame based on "Freedom" column
# Will sort from lowest to highest if no other parameter is passed
freedom_df = happiness_df.sort_values("Freedom")
freedom_df.head()
# Out:
#      Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 139   Angola             140            3.795      3.951642     3.638358
# 129    Sudan             130            4.139      4.345747     3.932253
# 144    Haiti             145            3.603      3.734715     3.471285
# 153  Burundi             154            2.905      3.074690     2.735310
# 151    Syria             152            3.462      3.663669     3.260331
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 139                  0.858428  1.104412                  0.049869  0.000000
# 129                  0.659517  1.214009                  0.290921  0.014996
# 144                  0.368610  0.640450                  0.277321  0.030370
# 153                  0.091623  0.629794                  0.151611  0.059901
# 151                  0.777153  0.396103                  0.500533  0.081539
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 139    0.097926                       0.069720           1.614482
# 129    0.182317                       0.089848           1.687066
# 144    0.489204                       0.099872           1.697168
# 153    0.204435                       0.084148           1.683024
# 151    0.493664                       0.151347           1.061574

# %%
# To sort from highest to lowest, ascending=False must be passed in
freedom_df = happiness_df.sort_values("Freedom", ascending=False)
freedom_df.head()
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# 0        Norway               1            7.537      7.594445     7.479556
# 128    Cambodia             129            4.168      4.278518     4.057483
# 2       Iceland               3            7.504      7.622030     7.385970
# 1       Denmark               2            7.522      7.581728     7.462272
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 46                   0.786441  1.548969                  0.498273  0.658249
# 0                    1.616463  1.533524                  0.796667  0.635423
# 128                  0.601765  1.006238                  0.429783  0.633376
# 2                    1.480633  1.610574                  0.833552  0.627163
# 1                    1.482383  1.551122                  0.792566  0.626007
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 46     0.415984                       0.246528           1.816914
# 0      0.362012                       0.315964           2.277027
# 128    0.385923                       0.068106           1.042941
# 2      0.475540                       0.153527           2.322715
# 1      0.355280                       0.400770           2.313707

# %%
# It is possible to sort based upon multiple columns
family_and_generosity = happiness_df.sort_values(
    ["Family", "Generosity"], ascending=False)
family_and_generosity.head()
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 2       Iceland               3            7.504      7.622030     7.385970
# 14      Ireland              15            6.977      7.043352     6.910649
# 1       Denmark               2            7.522      7.581728     7.462272
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# 7   New Zealand               8            7.314      7.379510     7.248490
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 2                   1.480633  1.610574                  0.833552  0.627163
# 14                  1.535707  1.558231                  0.809783  0.573110
# 1                   1.482383  1.551122                  0.792566  0.626007
# 46                  0.786441  1.548969                  0.498273  0.658249
# 7                   1.405706  1.548195                  0.816760  0.614062
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 2     0.475540                       0.153527           2.322715
# 14    0.427858                       0.298388           1.773869
# 1     0.355280                       0.400770           2.313707
# 46    0.415984                       0.246528           1.816914
# 7     0.500005                       0.382817           2.046456

# %%
# To sort from highest to lowest, ascending=False must be passed in
freedom_df = happiness_df.sort_values("Freedom", ascending=False)
freedom_df.head()
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# 0        Norway               1            7.537      7.594445     7.479556
# 128    Cambodia             129            4.168      4.278518     4.057483
# 2       Iceland               3            7.504      7.622030     7.385970
# 1       Denmark               2            7.522      7.581728     7.462272
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 46                   0.786441  1.548969                  0.498273  0.658249
# 0                    1.616463  1.533524                  0.796667  0.635423
# 128                  0.601765  1.006238                  0.429783  0.633376
# 2                    1.480633  1.610574                  0.833552  0.627163
# 1                    1.482383  1.551122                  0.792566  0.626007
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 46     0.415984                       0.246528           1.816914
# 0      0.362012                       0.315964           2.277027
# 128    0.385923                       0.068106           1.042941
# 2      0.475540                       0.153527           2.322715
# 1      0.355280                       0.400770           2.313707

# %%
# The index can be reset to provide index numbers based on the new rankings
# drop default False 
# This resets the index to the default integer index 
new_index = family_and_generosity.reset_index(drop=True)
new_index.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0      Iceland               3            7.504      7.622030     7.385970
# 1      Ireland              15            6.977      7.043352     6.910649
# 2      Denmark               2            7.522      7.581728     7.462272
# 3   Uzbekistan              47            5.971      6.065538     5.876463
# 4  New Zealand               8            7.314      7.379510     7.248490
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.480633  1.610574                  0.833552  0.627163
# 1                  1.535707  1.558231                  0.809783  0.573110
# 2                  1.482383  1.551122                  0.792566  0.626007
# 3                  0.786441  1.548969                  0.498273  0.658249
# 4                  1.405706  1.548195                  0.816760  0.614062
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.475540                       0.153527           2.322715
# 1    0.427858                       0.298388           1.773869
# 2    0.355280                       0.400770           2.313707
# 3    0.415984                       0.246528           1.816914
# 4    0.500005                       0.382817           2.046456

# %% [markdown]
# ## Students Turn: Activity 9 Search For The Worst
#
# ### Instructions
#
#   * Read in the CSV file provided and print it to the screen.
#
#   * Print out a list of all of the values within the "Preferred Position" column.
#
#   * Select a value from this list and create a new DataFrame that only includes players who prefer that position.
#
#   * Sort the DataFrame based upon a player's skill in that position.
#
#   * Reset the index for the DataFrame so that the index is in order.
#
#   * Print out the statistics for the worst player in a position to the screen.

# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Create reference to CSV file
csv_path = "Resources/Soccer2018Data.csv"

# Import the CSV into a pandas DataFrame
soccer_2018_df = pd.read_csv(csv_path)
soccer_2018_df
# Out:
#                    Name  Age          Nationality  Overall  Potential  \
# 0     Cristiano Ronaldo   32             Portugal       94         94
# 1              L. Messi   30            Argentina       93         93
# 2                Neymar   25               Brazil       92         94
# 3            L. SuÃ¡rez   30              Uruguay       92         92
# 4              M. Neuer   31              Germany       92         92
# 5        R. Lewandowski   28               Poland       91         91
# 6                De Gea   26                Spain       90         92
# 7             E. Hazard   26              Belgium       90         91
# 8              T. Kroos   27              Germany       90         90
# 9           G. HiguaÃ­n   29            Argentina       90         90
# 10         Sergio Ramos   31                Spain       90         90
# 11         K. De Bruyne   26              Belgium       89         92
# 12          T. Courtois   25              Belgium       89         92
# 13          A. SÃ¡nchez   28                Chile       89         89
# 14           L. ModriÄ‡   31              Croatia       89         89
# 15              G. Bale   27                Wales       89         89
# 16           S. AgÃ¼ero   29            Argentina       89         89
# 17         G. Chiellini   32                Italy       89         89
# 18            G. Buffon   39                Italy       89         89
# 19            P. Dybala   23            Argentina       88         93
# 20             J. Oblak   24             Slovenia       88         93
# 21         A. Griezmann   26               France       88         91
# 22               Thiago   26                Spain       88         90
# 23        P. Aubameyang   28                Gabon       88         88
# 24           L. Bonucci   30                Italy       88         88
# 25           J. Boateng   28              Germany       88         88
# 26            D. GodÃ­n   31              Uruguay       88         88
# 27           M. Hummels   28              Germany       88         88
# 28             M. Ã–zil   28              Germany       88         88
# 29            H. Lloris   30               France       88         88
# ...                 ...  ...                  ...      ...        ...
# 6117          S. Piette   22               Canada       69         76
# 6118          P. Klandt   33              Germany       69         69
# 6119           C. Solly   26              England       69         71
# 6120         A. Ibrahim   26               Norway       69         72
# 6121          Joelinton   20               Brazil       69         76
# 6122          M. PuÄko   23             Slovenia       69         78
# 6123        M. Jakobsen   31              Denmark       69         69
# 6124         L. Peltier   30              England       69         69
# 6125        E. Andersen   24               Norway       69         72
# 6126        O. VranjeÅ¡   27   Bosnia Herzegovina       69         70
# 6127         P. Ziegler   27              Germany       69         70
# 6128         D. Wheater   30              England       69         69
# 6129            D. Boer   36          Netherlands       69         69
# 6130          M. Fedele   24          Switzerland       69         73
# 6131          J. Malhue   33                Chile       69         69
# 6132          K. Mrabti   23               Sweden       69         77
# 6133     Marlinito Dias   33               Brazil       69         69
# 6134          Y. Corona   29               Mexico       69         69
# 6135           S. Quinn   31  Republic of Ireland       69         69
# 6136       A. Crescenzi   25                Italy       69         71
# 6137         M. Sayouba   24          Ivory Coast       69         74
# 6138            Camacho   36                Spain       69         69
# 6139           G. Danic   35               France       69         69
# 6140      P. Ofosu-Ayeh   25                Ghana       69         72
# 6141      Pedro Coronas   26             Portugal       69         70
# 6142          M. Curado   22            Argentina       69         75
# 6143         A. Aldrete   29               Mexico       69         69
# 6144       Dani Toribio   28                Spain       69         70
# 6145         T. Tawatha   25               Israel       69         72
# 6146        L. Ceballos   30            Argentina       69          6
#
#                           Club Preferred Position   CAM    CB   CDM  ...   \
# 0               Real Madrid CF                 ST  89.0  53.0  62.0  ...
# 1                 FC Barcelona                 RW  92.0  45.0  59.0  ...
# 2          Paris Saint-Germain                 LW  88.0  46.0  59.0  ...
# 3                 FC Barcelona                 ST  87.0  58.0  65.0  ...
# 4             FC Bayern Munich                 GK   NaN   NaN   NaN  ...
# 5             FC Bayern Munich                 ST  84.0  57.0  62.0  ...
# 6            Manchester United                 GK   NaN   NaN   NaN  ...
# 7                      Chelsea                 LW  88.0  47.0  61.0  ...
# 8               Real Madrid CF                CDM  83.0  72.0  82.0  ...
# 9                     Juventus                 ST  81.0  46.0  52.0  ...
# 10              Real Madrid CF                 CB  70.0  87.0  83.0  ...
# 11             Manchester City                 RM  86.0  57.0  70.0  ...
# 12                     Chelsea                 GK   NaN   NaN   NaN  ...
# 13                     Arsenal                 RM  85.0  56.0  64.0  ...
# 14              Real Madrid CF                CDM  86.0  72.0  80.0  ...
# 15              Real Madrid CF                 RW  86.0  67.0  71.0  ...
# 16             Manchester City                 ST  85.0  44.0  54.0  ...
# 17                    Juventus                 CB  55.0  86.0  76.0  ...
# 18                    Juventus                 GK   NaN   NaN   NaN  ...
# 19                    Juventus                 ST  86.0  43.0  55.0  ...
# 20            AtlÃ©tico Madrid                 GK   NaN   NaN   NaN  ...
# 21            AtlÃ©tico Madrid                 LW  84.0  48.0  57.0  ...
# 22            FC Bayern Munich                CDM  86.0  66.0  76.0  ...
# 23           Borussia Dortmund                 ST  82.0  52.0  59.0  ...
# 24                       Milan                 CB  68.0  86.0  83.0  ...
# 25            FC Bayern Munich                 CB  67.0  85.0  82.0  ...
# 26            AtlÃ©tico Madrid                 CB  63.0  86.0  80.0  ...
# 27            FC Bayern Munich                 CB  71.0  85.0  83.0  ...
# 28                     Arsenal                 RW  85.0  41.0  57.0  ...
# 29           Tottenham Hotspur                 GK   NaN   NaN   NaN  ...
# ...                        ...                ...   ...   ...   ...  ...
# 6117           Montreal Impact                CDM  59.0  68.0  68.0  ...
# 6118               SC Freiburg                 GK   NaN   NaN   NaN  ...
# 6119         Charlton Athletic                 RB  58.0  68.0  66.0  ...
# 6120        VÃ¥lerenga Fotball                 CM  67.0  67.0  68.0  ...
# 6121             SK Rapid Wien                CAM  66.0  53.0  55.0  ...
# 6122               Real Oviedo                 LM  68.0  42.0  48.0  ...
# 6123            Melbourne City                 CB  54.0  68.0  64.0  ...
# 6124              Cardiff City                 RB  58.0  71.0  67.0  ...
# 6125          StrÃ¸msgodset IF                 ST  68.0  43.0  49.0  ...
# 6126                AEK Athens                 RB  58.0  68.0  65.0  ...
# 6127      1. FC Kaiserslautern                 CB  56.0  69.0  68.0  ...
# 9         G. HiguaÃ­n   29   Argentina       90         90          Juventus
# 16         S. AgÃ¼ero   29   Argentina       89         89   Manchester City
#
#    Preferred Position   CAM    CB   CDM  ...     RB   RCB   RCM   RDM    RF  \
# 0                  ST  89.0  53.0  62.0  ...   61.0  53.0  82.0  62.0  91.0
# 3                  ST  87.0  58.0  65.0  ...   64.0  58.0  80.0  65.0  88.0
# 5                  ST  84.0  57.0  62.0  ...   58.0  57.0  78.0  62.0  87.0
# 9                  ST  81.0  46.0  52.0  ...   51.0  46.0  71.0  52.0  84.0
# 16                 ST  85.0  44.0  54.0  ...   52.0  44.0  75.0  54.0  87.0
#
#       RM    RS    RW   RWB    ST
# 0   89.0  92.0  91.0  66.0  92.0
# 3   85.0  88.0  87.0  68.0  88.0
# 5   82.0  88.0  84.0  61.0  88.0
# 9   79.0  87.0  82.0  55.0  87.0
# 16  84.0  86.0  86.0  57.0  86.0
#
# [5 rows x 33 columns]

# %%
# Sort the DataFrame by the values in the "ST" column to find the worst
strikers_2018_df = strikers_2018_df.sort_values("ST")

# Reset the index so that the index is now based on the sorting locations
strikers_2018_df = strikers_2018_df.reset_index(drop=True)
strikers_2018_df.head()
# Out:
#              Name  Age   Nationality  Overall  Potential               Club  \
# 0    M. PavloviÄ‡   27       Croatia       71         72         Angers SCO
# 1       K. Mrabti   23        Sweden       69         77    DjurgÃ¥rdens IF
# 2  M. Al Shalhoub   36  Saudi Arabia       70         70           Al Hilal
# 3         Willyan   23        Brazil       70         75  VitÃ³ria SetÃºbal
# 4       M. Jacobs   25       England       69         71     Wigan Athletic
#
#   Preferred Position   CAM    CB   CDM  ...     RB   RCB   RCM   RDM    RF  \
# 0                 ST  53.0  70.0  64.0  ...   59.0  70.0  57.0  64.0  55.0
# 1                 ST  68.0  57.0  62.0  ...   61.0  57.0  65.0  62.0  66.0
# 2                 ST  69.0  39.0  50.0  ...   45.0  39.0  66.0  50.0  66.0
# 3                 ST  68.0  52.0  59.0  ...   60.0  52.0  65.0  59.0  67.0
# 4                 ST  67.0  53.0  58.0  ...   59.0  53.0  65.0  58.0  66.0
#
#      RM    RS    RW   RWB    ST
# 0  52.0  60.0  52.0  58.0  60.0
# 1  69.0  62.0  68.0  63.0  62.0
# 2  66.0  62.0  67.0  49.0  62.0
# 3  69.0  63.0  69.0  62.0  63.0
# 4  68.0  63.0  68.0  61.0  63.0
#
# [5 rows x 33 columns]

# %%
# Save all of the information collected on the worst striker
worst_striker = strikers_2018_df.iloc[0]
worst_striker
# Out:
# Name                  M. PavloviÄ‡
# Age                             27
# Nationality                Croatia
# Overall                         71
# Potential                       72
# Club                    Angers SCO
# Preferred Position              ST
# CAM                             53
# CB                              70
# CDM                             64
# CF                              55
# CM                              57
# LAM                             53
# LB                              59
# LCB                             70
# LCM                             57
# LDM                             64
# LF                              55
# LM                              52
# LS                              60
# LW                              52
# LWB                             58
# RAM                             53
# RB                              59
# RCB                             70
# RCM                             57
# RDM                             64
# RF                              55
# RM                              52
# RS                              60
# RW                              52
# RWB                             58
# ST                              60
# Name: 0, dtype: object
